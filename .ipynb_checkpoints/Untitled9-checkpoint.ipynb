# %%
import torch
import ultralytics

print(torch.__version__)  # Check PyTorch version
print(ultralytics.__version__)  # Check Ultralytics version
# Out:
# Creating new Ultralytics Settings v0.0.6 file
# View Ultralytics Settings with 'yolo settings' or at 'C:\Users\fazila\AppData\Roaming\Ultralytics\settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# 2.6.0+cpu
# 8.3.74

# %%
mv C:\Users\fazila\OneDrive\Desktop\yolov8\ultralytics-main
# Out:
#   Cell In[1], line 1
#     mv C:\Users\fazila\OneDrive\Desktop\yolov8\ultralytics-main
#        ^
# SyntaxError: invalid syntax

# %%
mv "C:\Users\fazila\OneDrive\Desktop\yolov8\ultralytics-main" "C:\Users\fazila\OneDrive\Desktop\yolov8\destination_folder"
# Out:
#   Cell In[2], line 1
#     mv "C:\Users\fazila\OneDrive\Desktop\yolov8\ultralytics-main" "C:\Users\fazila\OneDrive\Desktop\yolov8\destination_folder"
#        ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
move "C:\Users\fazila\OneDrive\Desktop\yolov8\ultralytics-main" "C:\Users\fazila\OneDrive\Desktop\yolov8\destination_folder"
# Out:
#   Cell In[3], line 1
#     move "C:\Users\fazila\OneDrive\Desktop\yolov8\ultralytics-main" "C:\Users\fazila\OneDrive\Desktop\yolov8\destination_folder"
#          ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
# !move "C:\Users\fazila\OneDrive\Desktop\yolov8\ultralytics-main" "C:\Users\fazila\OneDrive\Desktop\yolov8\destination_folder"
# Out:
#         1 dir(s) moved.
