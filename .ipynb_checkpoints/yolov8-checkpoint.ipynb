# %%
import os
print(os.getcwd())  # Prints the current directory
# Out:
# C:\Users\fazila

# %%
os.chdir(r"C:\Users\fazila\OneDrive\Desktop\yolov8\YOLO-v8-Object-Detection-main")  # Replace with your actual file location
print("New directory:", os.getcwd())
# Out:
# New directory: C:\Users\fazila\OneDrive\Desktop\yolov8\YOLO-v8-Object-Detection-main

# %%
print(os.listdir())  # Verify if the file is now visible
# Out:
# ['YOLO-v8-Object-Detection-main', 'YOLO-v8-Object-Detection-main.lnk']
